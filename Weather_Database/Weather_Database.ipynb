# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | turukhansk
# Processing Record 2 of Set 1 | nanortalik
# Processing Record 3 of Set 1 | acri
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | kurya
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | olafsvik
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | tucupita
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | praia da vitoria
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | ekhabi
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | yar-sale
# Processing Record 21 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 1 | filadelfia
# Processing Record 23 of Set 1 | vardo
# Processing Record 24 of Set 1 | kama
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | conceicao do araguaia
# Processing Record 31 of Set 1 | porto velho
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | dingle
# Processing Record 35 of Set 1 | tura
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | daru
# Processing Record 38 of Set 1 | saravan
# Processing Record 39 of Set 1 | srednekolymsk
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | pontes e lacerda
# Processing Record 44 of Set 1 | tautira
# Processing Record 45 of Set 1 | kenai
# Processing Record 46 of Set 1 | isangel
# Processing Record 47 of Set 1 | rio grande
# Processing Record 48 of Set 1 | barrhead
# Processing Record 49 of Set 1 | coquimbo
# Processing Record 50 of Set 1 | salinas
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | leningradskiy
# Processing Record 3 of Set 2 | los llanos de aridane
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | kohat
# Processing Record 6 of Set 2 | standerton
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | kachiry
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | peniche
# Processing Record 12 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 13 of Set 2 | oranjemund
# Processing Record 14 of Set 2 | kavaratti
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 2 | kinanah
# City not found. Skipping...
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | atasu
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | zhigansk
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | faya
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | guerrero negro
# Processing Record 30 of Set 2 | moba
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | poum
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | koboldo
# City not found. Skipping...
# Processing Record 35 of Set 2 | bara
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | alyangula
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | port macquarie
# Processing Record 40 of Set 2 | eyl
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | suna
# Processing Record 43 of Set 2 | laguna
# Processing Record 44 of Set 2 | broome
# Processing Record 45 of Set 2 | vila velha
# Processing Record 46 of Set 2 | arman
# Processing Record 47 of Set 2 | rio gallegos
# Processing Record 48 of Set 2 | tucurui
# Processing Record 49 of Set 2 | gat
# Processing Record 50 of Set 2 | kozhva
# Processing Record 1 of Set 3 | isiro
# Processing Record 2 of Set 3 | grindavik
# Processing Record 3 of Set 3 | hambantota
# Processing Record 4 of Set 3 | klokkarvik
# City not found. Skipping...
# Processing Record 5 of Set 3 | jian
# Processing Record 6 of Set 3 | korla
# Processing Record 7 of Set 3 | karratha
# Processing Record 8 of Set 3 | santa vitoria do palmar
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | pangnirtung
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | bambous virieux
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | bubaque
# Processing Record 15 of Set 3 | tiksi
# Processing Record 16 of Set 3 | sainte-agathe-des-monts
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | kristinehamn
# Processing Record 19 of Set 3 | puerto del rosario
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | porto murtinho
# Processing Record 22 of Set 3 | touba
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | huarmey
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | naze
# Processing Record 28 of Set 3 | aklavik
# Processing Record 29 of Set 3 | namie
# Processing Record 30 of Set 3 | tomatlan
# Processing Record 31 of Set 3 | jha jha
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | acari
# Processing Record 34 of Set 3 | marzuq
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | kosh-agach
# Processing Record 37 of Set 3 | esperance
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | inyonga
# Processing Record 40 of Set 3 | maldonado
# Processing Record 41 of Set 3 | araouane
# Processing Record 42 of Set 3 | sulangan
# Processing Record 43 of Set 3 | coihaique
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | tahmek
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | cherskiy
# Processing Record 49 of Set 3 | padang
# Processing Record 50 of Set 3 | dabwali
# Processing Record 1 of Set 4 | brownsville
# Processing Record 2 of Set 4 | fukue
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | baykit
# Processing Record 5 of Set 4 | vilyuysk
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | chabahar
# Processing Record 9 of Set 4 | vestmannaeyjar
# Processing Record 10 of Set 4 | vestmanna
# Processing Record 11 of Set 4 | moroni
# Processing Record 12 of Set 4 | ornskoldsvik
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | lagoa
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | medicine hat
# Processing Record 17 of Set 4 | elko
# Processing Record 18 of Set 4 | serebryansk
# Processing Record 19 of Set 4 | durban
# Processing Record 20 of Set 4 | san cristobal
# Processing Record 21 of Set 4 | noumea
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 4 | jining
# Processing Record 25 of Set 4 | hillsborough
# Processing Record 26 of Set 4 | margate
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | altay
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | santa cruz de tenerife
# Processing Record 31 of Set 4 | caxito
# Processing Record 32 of Set 4 | obo
# Processing Record 33 of Set 4 | nong chik
# Processing Record 34 of Set 4 | marsh harbour
# Processing Record 35 of Set 4 | portland
# Processing Record 36 of Set 4 | maniitsoq
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | inuvik
# Processing Record 39 of Set 4 | fujin
# Processing Record 40 of Set 4 | hofn
# Processing Record 41 of Set 4 | moratuwa
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | bardsir
# Processing Record 45 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 4 | cerrito
# Processing Record 47 of Set 4 | point fortin
# Processing Record 48 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 4 | dudinka
# Processing Record 50 of Set 4 | dunedin
# Processing Record 1 of Set 5 | sinjai
# Processing Record 2 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 3 of Set 5 | beringovskiy
# Processing Record 4 of Set 5 | calolziocorte
# Processing Record 5 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 5 | avarua
# Processing Record 7 of Set 5 | mahenge
# Processing Record 8 of Set 5 | harper
# Processing Record 9 of Set 5 | anse-bertrand
# Processing Record 10 of Set 5 | ilulissat
# Processing Record 11 of Set 5 | kieta
# Processing Record 12 of Set 5 | do rud
# City not found. Skipping...
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | hilo
# Processing Record 15 of Set 5 | badaojiang
# City not found. Skipping...
# Processing Record 16 of Set 5 | hermanus
# Processing Record 17 of Set 5 | rundu
# Processing Record 18 of Set 5 | kangaatsiaq
# Processing Record 19 of Set 5 | brigantine
# Processing Record 20 of Set 5 | mogadishu
# Processing Record 21 of Set 5 | shenjiamen
# Processing Record 22 of Set 5 | luanda
# Processing Record 23 of Set 5 | vila franca do campo
# Processing Record 24 of Set 5 | jiuquan
# Processing Record 25 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 5 | staroaleyskoye
# Processing Record 27 of Set 5 | humaita
# Processing Record 28 of Set 5 | tadine
# Processing Record 29 of Set 5 | garmsar
# Processing Record 30 of Set 5 | port alfred
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 5 | opuwo
# Processing Record 34 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 5 | khatanga
# Processing Record 36 of Set 5 | rocky mountain house
# Processing Record 37 of Set 5 | tual
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | sioux lookout
# Processing Record 40 of Set 5 | alta floresta
# Processing Record 41 of Set 5 | pacific grove
# Processing Record 42 of Set 5 | sabzevar
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | pires do rio
# Processing Record 45 of Set 5 | ormond beach
# Processing Record 46 of Set 5 | uray
# Processing Record 47 of Set 5 | mugla
# Processing Record 48 of Set 5 | berlevag
# Processing Record 49 of Set 5 | nangong
# Processing Record 50 of Set 5 | mitu
# Processing Record 1 of Set 6 | muramatsu
# Processing Record 2 of Set 6 | sayyan
# Processing Record 3 of Set 6 | privokzalnyy
# City not found. Skipping...
# Processing Record 4 of Set 6 | norman wells
# Processing Record 5 of Set 6 | aleksandrov gay
# Processing Record 6 of Set 6 | waingapu
# Processing Record 7 of Set 6 | ponta do sol
# Processing Record 8 of Set 6 | saint-pierre
# Processing Record 9 of Set 6 | ulladulla
# Processing Record 10 of Set 6 | takaka
# Processing Record 11 of Set 6 | henties bay
# Processing Record 12 of Set 6 | flinders
# Processing Record 13 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 6 | cabo san lucas
# Processing Record 15 of Set 6 | tiznit
# Processing Record 16 of Set 6 | chernyshevskiy
# Processing Record 17 of Set 6 | verrettes
# Processing Record 18 of Set 6 | saint anthony
# Processing Record 19 of Set 6 | tazovskiy
# Processing Record 20 of Set 6 | hovd
# Processing Record 21 of Set 6 | paragominas
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | egvekinot
# Processing Record 24 of Set 6 | matagami
# Processing Record 25 of Set 6 | borogontsy
# Processing Record 26 of Set 6 | say
# Processing Record 27 of Set 6 | asau
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | agadez
# Processing Record 30 of Set 6 | bernalillo
# Processing Record 31 of Set 6 | itarema
# Processing Record 32 of Set 6 | cidreira
# Processing Record 33 of Set 6 | chuy
# Processing Record 34 of Set 6 | zomin
# Processing Record 35 of Set 6 | bauchi
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | lukaya
# Processing Record 38 of Set 6 | esmeralda
# Processing Record 39 of Set 6 | adrar
# Processing Record 40 of Set 6 | longyearbyen
# Processing Record 41 of Set 6 | cuenca
# Processing Record 42 of Set 6 | vangaindrano
# Processing Record 43 of Set 6 | mlonggo
# Processing Record 44 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 6 | palora
# Processing Record 46 of Set 6 | saint george
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | havre-saint-pierre
# Processing Record 49 of Set 6 | kungurtug
# Processing Record 50 of Set 6 | mecca
# Processing Record 1 of Set 7 | rocha
# Processing Record 2 of Set 7 | kardla
# Processing Record 3 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 7 | samarai
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | andenes
# Processing Record 7 of Set 7 | waipawa
# Processing Record 8 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 7 | kirakira
# Processing Record 10 of Set 7 | temnikov
# Processing Record 11 of Set 7 | moussoro
# Processing Record 12 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 7 | bonfim
# Processing Record 14 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 7 | chastoozerye
# City not found. Skipping...
# Processing Record 16 of Set 7 | kampot
# Processing Record 17 of Set 7 | vilhena
# Processing Record 18 of Set 7 | meridian
# Processing Record 19 of Set 7 | rengo
# Processing Record 20 of Set 7 | mehamn
# Processing Record 21 of Set 7 | kindu
# Processing Record 22 of Set 7 | te anau
# Processing Record 23 of Set 7 | obidos
# Processing Record 24 of Set 7 | sinjar
# Processing Record 25 of Set 7 | kombissiri
# Processing Record 26 of Set 7 | kidal
# Processing Record 27 of Set 7 | udachnyy
# Processing Record 28 of Set 7 | antalaha
# Processing Record 29 of Set 7 | oktyabrskiy
# Processing Record 30 of Set 7 | kaeo
# Processing Record 31 of Set 7 | linxia
# Processing Record 32 of Set 7 | loukhi
# Processing Record 33 of Set 7 | kruisfontein
# Processing Record 34 of Set 7 | bowen
# Processing Record 35 of Set 7 | saldanha
# Processing Record 36 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 37 of Set 7 | trofors
# Processing Record 38 of Set 7 | zhezkazgan
# Processing Record 39 of Set 7 | the valley
# Processing Record 40 of Set 7 | mandalgovi
# Processing Record 41 of Set 7 | roald
# Processing Record 42 of Set 7 | igboho
# Processing Record 43 of Set 7 | austin
# Processing Record 44 of Set 7 | kuznechnoye
# Processing Record 45 of Set 7 | seydi
# Processing Record 46 of Set 7 | leninsk
# Processing Record 47 of Set 7 | lavrentiya
# Processing Record 48 of Set 7 | plainview
# Processing Record 49 of Set 7 | murom
# Processing Record 50 of Set 7 | gubkinskiy
# Processing Record 1 of Set 8 | kabwe
# Processing Record 2 of Set 8 | sabang
# Processing Record 3 of Set 8 | ulaangom
# Processing Record 4 of Set 8 | barentu
# Processing Record 5 of Set 8 | bend
# Processing Record 6 of Set 8 | lafiagi
# Processing Record 7 of Set 8 | odweyne
# Processing Record 8 of Set 8 | elk point
# Processing Record 9 of Set 8 | marrakesh
# Processing Record 10 of Set 8 | yumen
# Processing Record 11 of Set 8 | hrodna
# Processing Record 12 of Set 8 | luderitz
# Processing Record 13 of Set 8 | princeton
# Processing Record 14 of Set 8 | carmen
# Processing Record 15 of Set 8 | severo-kurilsk
# Processing Record 16 of Set 8 | kattivakkam
# Processing Record 17 of Set 8 | souillac
# Processing Record 18 of Set 8 | liwale
# Processing Record 19 of Set 8 | gizo
# Processing Record 20 of Set 8 | nago
# Processing Record 21 of Set 8 | lesozavodsk
# Processing Record 22 of Set 8 | namibe
# Processing Record 23 of Set 8 | danielskuil
# Processing Record 24 of Set 8 | yenagoa
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | the pas
# Processing Record 27 of Set 8 | horsham
# Processing Record 28 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 8 | chateaubelair
# Processing Record 30 of Set 8 | qasigiannguit
# Processing Record 31 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 8 | saint-leu
# Processing Record 33 of Set 8 | solwezi
# Processing Record 34 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 8 | garowe
# Processing Record 36 of Set 8 | kargopol
# Processing Record 37 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 38 of Set 8 | alenquer
# Processing Record 39 of Set 8 | qandala
# Processing Record 40 of Set 8 | byron bay
# Processing Record 41 of Set 8 | yuzhou
# Processing Record 42 of Set 8 | eruwa
# Processing Record 43 of Set 8 | kisangani
# Processing Record 44 of Set 8 | honningsvag
# Processing Record 45 of Set 8 | fernie
# Processing Record 46 of Set 8 | hasaki
# Processing Record 47 of Set 8 | gamba
# Processing Record 48 of Set 8 | raudeberg
# Processing Record 49 of Set 8 | road town
# Processing Record 50 of Set 8 | marystown
# Processing Record 1 of Set 9 | kajaani
# Processing Record 2 of Set 9 | thunder bay
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | ateli
# Processing Record 5 of Set 9 | selma
# Processing Record 6 of Set 9 | grimshaw
# Processing Record 7 of Set 9 | dawlatabad
# Processing Record 8 of Set 9 | caborca
# Processing Record 9 of Set 9 | praia
# Processing Record 10 of Set 9 | lokot
# Processing Record 11 of Set 9 | baruun-urt
# Processing Record 12 of Set 9 | richards bay
# Processing Record 13 of Set 9 | omsukchan
# Processing Record 14 of Set 9 | sao filipe
# Processing Record 15 of Set 9 | aksu
# Processing Record 16 of Set 9 | awbari
# Processing Record 17 of Set 9 | barao de melgaco
# Processing Record 18 of Set 9 | peleduy
# Processing Record 19 of Set 9 | mosquera
# Processing Record 20 of Set 9 | sidi ali
# Processing Record 21 of Set 9 | ferkessedougou
# Processing Record 22 of Set 9 | santa isabel do rio negro
# Processing Record 23 of Set 9 | tangier
# Processing Record 24 of Set 9 | marienburg
# Processing Record 25 of Set 9 | lubango
# Processing Record 26 of Set 9 | krasnovishersk
# Processing Record 27 of Set 9 | colquiri
# Processing Record 28 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 29 of Set 9 | iberia
# Processing Record 30 of Set 9 | rosarito
# Processing Record 31 of Set 9 | carutapera
# Processing Record 32 of Set 9 | lucapa
# Processing Record 33 of Set 9 | moose factory
# Processing Record 34 of Set 9 | boddam
# Processing Record 35 of Set 9 | is
# City not found. Skipping...
# Processing Record 36 of Set 9 | banda aceh
# Processing Record 37 of Set 9 | paamiut
# Processing Record 38 of Set 9 | maneadero
# Processing Record 39 of Set 9 | tilichiki
# Processing Record 40 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 9 | shirdi
# Processing Record 42 of Set 9 | moree
# Processing Record 43 of Set 9 | onega
# Processing Record 44 of Set 9 | zheleznodorozhnyy
# Processing Record 45 of Set 9 | kuala terengganu
# Processing Record 46 of Set 9 | kisanga
# Processing Record 47 of Set 9 | panzhihua
# Processing Record 48 of Set 9 | san andres
# Processing Record 49 of Set 9 | la reforma
# Processing Record 50 of Set 9 | alice springs
# Processing Record 1 of Set 10 | emerald
# Processing Record 2 of Set 10 | iyo
# Processing Record 3 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 10 | nantucket
# Processing Record 5 of Set 10 | puerto madero
# Processing Record 6 of Set 10 | angoram
# Processing Record 7 of Set 10 | sisimiut
# Processing Record 8 of Set 10 | inongo
# Processing Record 9 of Set 10 | nabire
# Processing Record 10 of Set 10 | baghdad
# Processing Record 11 of Set 10 | hesla
# Processing Record 12 of Set 10 | sattahip
# Processing Record 13 of Set 10 | nouadhibou
# Processing Record 14 of Set 10 | valparaiso
# Processing Record 15 of Set 10 | manta
# Processing Record 16 of Set 10 | san quintin
# Processing Record 17 of Set 10 | sola
# Processing Record 18 of Set 10 | monrovia
# Processing Record 19 of Set 10 | aykhal
# Processing Record 20 of Set 10 | yulara
# Processing Record 21 of Set 10 | ocos
# Processing Record 22 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 10 | kendari
# Processing Record 24 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 10 | hualmay
# Processing Record 26 of Set 10 | suntar
# Processing Record 27 of Set 10 | sorland
# Processing Record 28 of Set 10 | taltal
# Processing Record 29 of Set 10 | balila
# Processing Record 30 of Set 10 | quatre cocos
# Processing Record 31 of Set 10 | canhotinho
# Processing Record 32 of Set 10 | russell
# Processing Record 33 of Set 10 | tres arroyos
# Processing Record 34 of Set 10 | cabedelo
# Processing Record 35 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 36 of Set 10 | ust-ishim
# Processing Record 37 of Set 10 | cordoba
# Processing Record 38 of Set 10 | dalby
# Processing Record 39 of Set 10 | takoradi
# Processing Record 40 of Set 10 | tottori
# Processing Record 41 of Set 10 | cairns
# Processing Record 42 of Set 10 | kindersley
# Processing Record 43 of Set 10 | alexandria
# Processing Record 44 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 10 | bismarck
# Processing Record 46 of Set 10 | presidencia roque saenz pena
# Processing Record 47 of Set 10 | saint simons
# Processing Record 48 of Set 10 | kells
# Processing Record 49 of Set 10 | deputatskiy
# Processing Record 50 of Set 10 | carlagan
# Processing Record 1 of Set 11 | tervel
# Processing Record 2 of Set 11 | puteyets
# Processing Record 3 of Set 11 | blagoyevo
# Processing Record 4 of Set 11 | almaznyy
# Processing Record 5 of Set 11 | bandarbeyla
# Processing Record 6 of Set 11 | garissa
# Processing Record 7 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 8 of Set 11 | morant bay
# Processing Record 9 of Set 11 | planaltina
# Processing Record 10 of Set 11 | esmeraldas
# Processing Record 11 of Set 11 | kilindoni
# Processing Record 12 of Set 11 | bima
# Processing Record 13 of Set 11 | kokstad
# Processing Record 14 of Set 11 | dovolnoye
# Processing Record 15 of Set 11 | kashi
# Processing Record 16 of Set 11 | san rafael
# Processing Record 17 of Set 11 | iskateley
# Processing Record 18 of Set 11 | japura
# Processing Record 19 of Set 11 | verkhoyansk
# Processing Record 20 of Set 11 | todos santos
# Processing Record 21 of Set 11 | talnakh
# Processing Record 22 of Set 11 | bonavista
# Processing Record 23 of Set 11 | pisco
# Processing Record 24 of Set 11 | leopold
# Processing Record 25 of Set 11 | mehran
# Processing Record 26 of Set 11 | kemin
# Processing Record 27 of Set 11 | okha
# Processing Record 28 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 11 | kathmandu
# Processing Record 30 of Set 11 | candia
# Processing Record 31 of Set 11 | hay river
# Processing Record 32 of Set 11 | vila
# Processing Record 33 of Set 11 | petrovskaya
# Processing Record 34 of Set 11 | northam
# Processing Record 35 of Set 11 | ishim
# Processing Record 36 of Set 11 | milverton
# Processing Record 37 of Set 11 | vredendal
# Processing Record 38 of Set 11 | hervey bay
# Processing Record 39 of Set 11 | leh
# Processing Record 40 of Set 11 | puri
# Processing Record 41 of Set 11 | changying
# Processing Record 42 of Set 11 | eirunepe
# Processing Record 43 of Set 11 | riverton
# Processing Record 44 of Set 11 | sawtell
# Processing Record 45 of Set 11 | qunduz
# Processing Record 46 of Set 11 | pokrovskoye
# Processing Record 47 of Set 11 | obihiro
# Processing Record 48 of Set 11 | oussouye
# Processing Record 49 of Set 11 | buala
# Processing Record 50 of Set 11 | ostrovnoy
# Processing Record 1 of Set 12 | port lincoln
# Processing Record 2 of Set 12 | grand gaube
# Processing Record 3 of Set 12 | lipari
# Processing Record 4 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 5 of Set 12 | wanxian
# Processing Record 6 of Set 12 | port-gentil
# Processing Record 7 of Set 12 | malyye derbety
# Processing Record 8 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 12 | avera
# Processing Record 11 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 12 | ketchikan
# Processing Record 13 of Set 12 | kutum
# Processing Record 14 of Set 12 | metehara
# City not found. Skipping...
# Processing Record 15 of Set 12 | amapa
# Processing Record 16 of Set 12 | san policarpo
# Processing Record 17 of Set 12 | parintins
# Processing Record 18 of Set 12 | nieuw nickerie
# Processing Record 19 of Set 12 | neumunster
# Processing Record 20 of Set 12 | cookeville
# Processing Record 21 of Set 12 | surovikino
# Processing Record 22 of Set 12 | dawan
# Processing Record 23 of Set 12 | teya
# Processing Record 24 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 12 | kamennogorsk
# Processing Record 27 of Set 12 | shaunavon
# Processing Record 28 of Set 12 | namtsy
# Processing Record 29 of Set 12 | veraval
# Processing Record 30 of Set 12 | ust-koksa
# Processing Record 31 of Set 12 | anaimalai
# Processing Record 32 of Set 12 | anloga
# Processing Record 33 of Set 12 | severnoye
# Processing Record 34 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 12 | garden city
# Processing Record 36 of Set 12 | college
# Processing Record 37 of Set 12 | baker city
# Processing Record 38 of Set 12 | vetlanda
# Processing Record 39 of Set 12 | wairoa
# Processing Record 40 of Set 12 | muros
# Processing Record 41 of Set 12 | culpeper
# Processing Record 42 of Set 12 | ilinskiy
# Processing Record 43 of Set 12 | forestville
# Processing Record 44 of Set 12 | jieshi
# Processing Record 45 of Set 12 | moranbah
# Processing Record 46 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 47 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 48 of Set 12 | marsaxlokk
# Processing Record 49 of Set 12 | san-pedro
# Processing Record 50 of Set 12 | hami
# Processing Record 1 of Set 13 | corinto
# Processing Record 2 of Set 13 | seoul
# Processing Record 3 of Set 13 | ballina
# Processing Record 4 of Set 13 | beloha
# Processing Record 5 of Set 13 | meulaboh
# Processing Record 6 of Set 13 | saint-jean-de-maurienne
# Processing Record 7 of Set 13 | puerto escondido
# Processing Record 8 of Set 13 | pyaozerskiy
# Processing Record 9 of Set 13 | dijkot
# Processing Record 10 of Set 13 | imphal
# Processing Record 11 of Set 13 | brae
# Processing Record 12 of Set 13 | belmonte
# Processing Record 13 of Set 13 | handan
# Processing Record 14 of Set 13 | itoman
# Processing Record 15 of Set 13 | laiagam
# City not found. Skipping...
# Processing Record 16 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 13 | caraballeda
# Processing Record 18 of Set 13 | kuryk
# Processing Record 19 of Set 13 | manbij
# Processing Record 20 of Set 13 | palmer
# Processing Record 21 of Set 13 | usvyaty
# Processing Record 22 of Set 13 | nyuksenitsa
# Processing Record 23 of Set 13 | whitianga
# Processing Record 24 of Set 13 | maningrida
# Processing Record 25 of Set 13 | krasnoselkup
# Processing Record 26 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 13 | skegness
# Processing Record 28 of Set 13 | gambissara
# Processing Record 29 of Set 13 | gobabis
# Processing Record 30 of Set 13 | atherton
# Processing Record 31 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | desaguadero
# Processing Record 33 of Set 13 | loutros
# Processing Record 34 of Set 13 | cap malheureux
# Processing Record 35 of Set 13 | sept-iles
# Processing Record 36 of Set 13 | arlit
# Processing Record 37 of Set 13 | beisfjord
# Processing Record 38 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 13 | atar
# Processing Record 40 of Set 13 | eston
# Processing Record 41 of Set 13 | luena
# Processing Record 42 of Set 13 | nianzishan
# Processing Record 43 of Set 13 | anadyr
# Processing Record 44 of Set 13 | smithers
# Processing Record 45 of Set 13 | poli
# Processing Record 46 of Set 13 | port hedland
# Processing Record 47 of Set 13 | yasnyy
# Processing Record 48 of Set 13 | north bend
# Processing Record 49 of Set 13 | bunia
# Processing Record 50 of Set 13 | manohar thana
# Processing Record 1 of Set 14 | nador
# Processing Record 2 of Set 14 | tuatapere
# Processing Record 3 of Set 14 | comodoro rivadavia
# Processing Record 4 of Set 14 | ahipara
# Processing Record 5 of Set 14 | cayenne
# Processing Record 6 of Set 14 | mandera
# Processing Record 7 of Set 14 | bilibino
# Processing Record 8 of Set 14 | salina cruz
# Processing Record 9 of Set 14 | prince george
# Processing Record 10 of Set 14 | nuevo progreso
# Processing Record 11 of Set 14 | kabakovo
# Processing Record 12 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 14 | nome
# Processing Record 14 of Set 14 | san javier
# Processing Record 15 of Set 14 | khuzhir
# Processing Record 16 of Set 14 | vostok
# Processing Record 17 of Set 14 | paita
# Processing Record 18 of Set 14 | lorengau
# Processing Record 19 of Set 14 | nambucca heads
# Processing Record 20 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 14 | alekseyevsk
# Processing Record 22 of Set 14 | batemans bay
# Processing Record 23 of Set 14 | praxedis guerrero
# Processing Record 24 of Set 14 | yarim
# Processing Record 25 of Set 14 | chapais
# Processing Record 26 of Set 14 | cermik
# Processing Record 27 of Set 14 | troitsko-pechorsk
# Processing Record 28 of Set 14 | swanzey
# Processing Record 29 of Set 14 | porto santo
# Processing Record 30 of Set 14 | mujiayingzi
# Processing Record 31 of Set 14 | ust-kuyga
# Processing Record 32 of Set 14 | bayan
# Processing Record 33 of Set 14 | hailar
# Processing Record 34 of Set 14 | acapulco
# Processing Record 35 of Set 14 | north ogden
# Processing Record 36 of Set 14 | pemba
# Processing Record 37 of Set 14 | manzil kamil
# Processing Record 38 of Set 14 | palaia fokaia
# Processing Record 39 of Set 14 | palauig
# Processing Record 40 of Set 14 | ambon
# Processing Record 41 of Set 14 | saint-francois
# Processing Record 42 of Set 14 | makakilo city
# Processing Record 43 of Set 14 | el tigre
# Processing Record 44 of Set 14 | bria
# Processing Record 45 of Set 14 | beberibe
# Processing Record 46 of Set 14 | wadi musa
# Processing Record 47 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 48 of Set 14 | plouzane
# Processing Record 49 of Set 14 | tabou
# Processing Record 50 of Set 14 | la ronge
# Processing Record 1 of Set 15 | karasjok
# Processing Record 2 of Set 15 | luau
# Processing Record 3 of Set 15 | chimoio
# Processing Record 4 of Set 15 | port blair
# Processing Record 5 of Set 15 | changji
# Processing Record 6 of Set 15 | skjervoy
# Processing Record 7 of Set 15 | bud
# Processing Record 8 of Set 15 | binzhou
# Processing Record 9 of Set 15 | kathu
# Processing Record 10 of Set 15 | mbuji-mayi
# Processing Record 11 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 15 | sobolevo
# Processing Record 13 of Set 15 | prachuap khiri khan
# Processing Record 14 of Set 15 | xiongzhou
# Processing Record 15 of Set 15 | shakawe
# Processing Record 16 of Set 15 | sur
# Processing Record 17 of Set 15 | antsohihy
# Processing Record 18 of Set 15 | severnyy
# Processing Record 19 of Set 15 | parana
# Processing Record 20 of Set 15 | grants
# Processing Record 21 of Set 15 | ilebo
# Processing Record 22 of Set 15 | poronaysk
# Processing Record 23 of Set 15 | cabadiangan
# Processing Record 24 of Set 15 | krasnozatonskiy
# Processing Record 25 of Set 15 | sistranda
# Processing Record 26 of Set 15 | mpongwe
# Processing Record 27 of Set 15 | havoysund
# Processing Record 28 of Set 15 | kismayo
# Processing Record 29 of Set 15 | kargat
# Processing Record 30 of Set 15 | kuusamo
# Processing Record 31 of Set 15 | dickinson
# Processing Record 32 of Set 15 | broken hill
# Processing Record 33 of Set 15 | fort nelson
# Processing Record 34 of Set 15 | porto walter
# Processing Record 35 of Set 15 | pedernales
# Processing Record 36 of Set 15 | fairbanks
# Processing Record 37 of Set 15 | masuguru
# Processing Record 38 of Set 15 | agadir
# Processing Record 39 of Set 15 | okhotsk
# Processing Record 40 of Set 15 | mitsamiouli
# Processing Record 41 of Set 15 | san julian
# Processing Record 42 of Set 15 | tame
# Processing Record 43 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 15 | muchkapskiy
# Processing Record 45 of Set 15 | khorinsk
# Processing Record 46 of Set 15 | pedasi
# Processing Record 47 of Set 15 | half moon bay
# Processing Record 48 of Set 15 | boguchany
# Processing Record 49 of Set 15 | solikamsk
# Processing Record 50 of Set 15 | kaspiyskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Turukhansk      RU  65.8167   87.9833     42.21        64           7
# 1       Nanortalik      GL  60.1432  -45.2371     36.19        53           0
# 2             Acri      IT  39.4929   16.3838     74.53        32           0
# 3        Busselton      AU -33.6500  115.3333     63.09        70         100
# 4     Punta Arenas      CL -53.1500  -70.9167     37.51        87           0
# ..             ...     ...      ...       ...       ...       ...         ...
# 679         Pedasi      PA   7.5333  -80.0333     76.06        84          86
# 680  Half Moon Bay      US  37.4636 -122.4286     63.14        90          90
# 681      Boguchany      RU  58.3814   97.4531     44.98        61         100
# 682      Solikamsk      RU  59.6196   56.7729     52.34        65         100
# 683     Kaspiyskiy      RU  45.3929   47.3707     64.00        51          94
#
#      Wind Speed Current Description
# 0         13.06           clear sky
# 1          4.25           clear sky
# 2          5.55           clear sky
# 3         13.62     overcast clouds
# 4          9.22           clear sky
# ..          ...                 ...
# 679        0.58     overcast clouds
# 680        1.01                mist
# 681        3.76     overcast clouds
# 682        7.23     overcast clouds
# 683        4.65     overcast clouds
#
# [684 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
